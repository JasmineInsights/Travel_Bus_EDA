# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('jr1.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Bus_Name         object
# Bus_type         object
# from             object
# to               object
# pickup_time      object
# drop_time        object
# duration          int64
# prices            int64
# ratings         float64
# AC_type          object
# Seater           object
# semi_sleeper     object
# sleeper          object
# dtype: object

# %%
df.isna().sum()
# Out:
# Bus_Name        0
# Bus_type        0
# from            0
# to              0
# pickup_time     0
# drop_time       0
# duration        0
# prices          0
# ratings         0
# AC_type         0
# Seater          0
# semi_sleeper    0
# sleeper         0
# dtype: int64

# %%
jr1=df

# %%
jr1
# Out:
#                           Bus_Name                    Bus_type from   to  \
# 0               IntrCity SmartBus   A/C Seater / Sleeper (2+1)  HYD  VJY
# 1               IntrCity SmartBus             AC Sleeper (2+1)  HYD  VJY
# 2               IntrCity SmartBus   A/C Seater / Sleeper (2+1)  HYD  VJY
# 3                      AdFRESHBUS    Electric A/C Seater (2+2)  HYD  VJY
# 4                           NueGo    Electric A/C Seater (2+2)  HYD  VJY
# ..                             ...                         ...  ...  ...
# 189                      Yolo Bus            A/C Sleeper (2+1)  HYD  VJY
# 190                Vahini Travels      NON A/C Push Back (2+2)  HYD  VJY
# 191  Sri Tulasi Tours and Travels   A/C Seater / Sleeper (2+1)  HYD  VJY
# 192  Sri Tulasi Tours and Travels   A/C Seater / Sleeper (2+1)  HYD  VJY
# 193  Sri Tulasi Tours and Travels            A/C Sleeper (2+1)  HYD  VJY
#
#     pickup_time drop_time  duration  prices  ratings  AC_type Seater  \
# ...

# %% [markdown]
# ### Histogram

# %% [markdown]
# ##### Prices of bustickets of HYD TO VJY

# %%
plt.figure(figsize=(8,3))
plt.hist(df['prices'],bins=10,color='purple')
plt.xlabel("Prices")
plt.ylabel("Frequency")
plt.title("Histogram of prices")
plt.show()

# %% [raw]
# insights:
#     1.hyd to vjy busticket prices ranges from 400 to 3500
#     2.most of the ticket prices ranges between 400 and 700
#     3.There are nearly 5 buses whose price 2000
#     4.majority of bus price ranges between 400 and 1400

# %% [markdown]
# ##### Ratings of bustickets from HYD TO VJY

# %%
plt.figure(figsize=(6,3))
plt.hist(df['ratings'],bins=10,color='red')
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.title("Histogram of ratings")
plt.show()

# %% [raw]
# insights:
#     1.Rating ranges between 1.0 and 5.0
#     2.significant number of buses are been rated with a 4.5 star rating
#     3.very few buses got 2.0 and bellow 2.0 star rating
#     4.there nearly 27 buses whose rating is 4.5
#     5.there is more than 35 buses whose rating ranges from 4.0 to 4.5
#     6.there is nearly 23 buse whose rating is 3.4
#     7.there is 15 buses whose rating ranges from 2.0 to 2.5

# %% [markdown]
# ### Density plot

# %% [markdown]
# ##### Prices of bustickets based on AC_type

# %%
plt.style.use('dark_background')
sns.histplot(data=df,x='prices',bins=20,color='red',hue='AC_type',kde=True).set(title='Prices of bustickets based on AC_type')
plt.show()

# %% [raw]
# insights:
#     1.a/c bus ticket prices ranges between 500 rupees to 3000 rupees
#     2.non a/c bus ticket prices ranges between 500  rupees to 3000 rupees
#     3.there are more ac buses above 1000 rupees
#     4.there is nearly 48 a/c buses whose price is  500 and 1000 rupees

# %% [markdown]
# ##### Density plot for prices and duration

# %%
plt.style.use('dark_background')
sns.kdeplot(data=df,x='prices',color='red',hue='duration').set(title='Density plot for prices and duration')
plt.show()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_4744\1381937493.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df,x='prices',color='red',hue='duration').set(title='Density plot for prices and duration')

# %% [markdown]
# ##### Prices of bustickets based on sleeper

# %%
sns.set_style('dark')
sns.histplot(data=df,x='prices',bins=20,color='red',hue='sleeper',kde=True).set(title='Prices of bustickets based on sleeper')
plt.show()

# %% [raw]
# insights:
#     1.sleeper bus ticket prices ranges between 500 to 3500
#     2.non sleeper ticket prices ranges between 500 to 1000
#     3.there are only sleeper buses above 1000
#     4.there is nearly 32 sleeper buses whose price is 500
#     5.there is neary 49 sleeper buses whose price ranges from 800-900

# %% [markdown]
# ##### Prices of bustickets based on seater

# %%
plt.style.use('classic')
sns.histplot(data=jr1,x='prices',bins=20,color='red',hue='Seater',kde=True).set(title='Prices of bustickets based on seater')
plt.show()

# %% [raw]
# insights:
#     1.seater bus ticket prices ranges between 500 to 2400
#     2.non seater ticket prices ranges between 500 to 3500
#     3.there are only non seater buses above 1000
#     4.there nearly 53  of seater bus price is 500
#     5.there is nearly 20 seater buses whose price ranges 800-900

# %% [markdown]
# ##### Prices of bustickets based on semi_seater

# %%
sns.set_style('darkgrid')
sns.histplot(data=jr1,x='prices',bins=20,color='purple',hue='semi_sleeper',kde=True).set(title='Prices of bustickets based on semi_seater')
plt.show()

# %% [raw]
# insights:
#     1.semi sleeper bus ticket prices ranges between 500 to 1000
#     2.non semi sleeper ticket prices ranges between 500 to 3500
#     3.there are only non semi_sleeper buses above 1000
#     4.majority of semi seater bus price is 500

# %% [markdown]
# ##### Prices of bustickets based on seater

# %%
plt.style.use('dark_background')
sns.histplot(data=jr1,x='ratings',bins=20,color='red',hue='Seater',kde=True).set(title='ratings of bustickets based on seater')
plt.show()

# %% [markdown]
# ### box plot

# %% [markdown]
# ##### outliers of ticket Prices based on AC_type  & sleeper

# %%
sns.set_style('darkgrid')
sns.boxplot(data=jr1,y='prices',x='sleeper',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & sleeper')
plt.show()

# %% [raw]
# insights:
#     1.there are 3 outliers in ac sleeper buses
#     2.there are 4 outliers for non ac sleeper
#     3.there is 1 outlier for ac non sleeper bus
#     4.there are no outliers for non ac sleeper and non ac non sleeper

# %% [markdown]
# ##### Outliers of ticket Prices based on AC_type & seater

# %%
plt.style.use('ggplot')
sns.boxplot(data=jr1,y='prices',x='Seater',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & seater')
plt.show()

# %% [raw]
# insights:
#     1.there are 2 outliers in ac seater buses
#     2.there is 6 outliers in non ac seater buses
#     3.there are 3 outliers in  ac non seater buses
#     4.there are no outliers in non ac non seater buses

# %% [markdown]
# ##### Outliers of ticket Prices based on AC_type & semi sleeper

# %%
sns.set_style('whitegrid')
sns.boxplot(data=jr1,y='prices',x='semi_sleeper',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & semi sleeper')
plt.show()

# %% [raw]
# insights:
#     1.there are 6 outliers in non ac non semi_sleeper buses
#     2.there are 2 outlier for ac non semi seater buses
#     3.there is 1outliers in non ac non semi_sleeper
#     3.there no buses of non ac semi seater

# %% [markdown]
# ### line chart

# %% [markdown]
# ##### Line chart for duration and prices

# %%
sns.lineplot(data=jr1,x='duration',y='prices',estimator='sum').set(title='Line chart for duration and prices')
plt.show()

# %% [raw]
# insights:
#     1.6hr duration buses has more ticket price.
#     2.duration increases price decrease.
#     3.above 6 hr duration the price is started decreasing
#     4.when the duration is 7 hrs the ticket price of the bus is 4000
#     5.when its 8hrs duration then the price is 1000
#     6.when its duration is less than 8 hrs then price decreases below 1000

# %% [markdown]
# ##### Line chart for ratings and prices

# %%
sns.lineplot(data=jr1,x='ratings',y='prices',estimator='sum').set(title='Line chart for ratings and prices')
plt.show()

# %% [raw]
# insights:
#     1.ratings is proportional to price
#     2.high rating buses has high prices
#     3.low rating buses has low prices
#     4.when the bus ticket price is 15000 then its rating is 4.0
#     5.below 5000 ticket bus price its having ratings ranges from 1.3 to below 2.5 ratings

# %% [markdown]
# ## Categorical

# %% [markdown]
# ### count plot

# %% [markdown]
# ##### Count of number of ac buses

# %%
sns.set_style('white')
plt.figure(figsize=(2,1))
sns.catplot(data=jr1,x='AC_type',kind='count').set(title='Count of number of ac buses')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['AC_type'].value_counts()
# Out:
# AC_type
# A/C        122
# NON A/C     72
# Name: count, dtype: int64

# %% [raw]
# insights:
#       1.there is 177 a/c buses
#       2.there is 26 non a/c buses

# %% [markdown]
# ##### Count of number of seater

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(4,3))
sns.countplot(data=jr1,x='Seater').set(title='Count of number of seater')
plt.show()

# %%
df['Seater'].value_counts()
# Out:
# Seater
# yes    121
# no      73
# Name: count, dtype: int64

# %% [raw]
# insights:
#     1.there is 126 seater buses
#     2.there is 77 non seater buses

# %% [markdown]
# ##### Count of number of sleeper

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=jr1,x='sleeper').set(title='Count of number of sleeper')
plt.show()

# %%
df['sleeper'].value_counts()
# Out:
# sleeper
# yes    158
# no      36
# Name: count, dtype: int64

# %% [raw]
# insights:
#     1.there is 167 sleeper buses
#     2.there is 36 non sleeper buses

# %% [markdown]
# ##### Count of number of semi sleeper

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=jr1,x='semi_sleeper').set(title='Count of number of semi sleeper')
plt.show()

# %%
df['semi_sleeper'].value_counts()
# Out:
# semi_sleeper
# no     184
# yes     10
# Name: count, dtype: int64

# %% [raw]
# insights:
#     1.there is 10 semi sleeper buses
#     2.there is 193 non semi sleeper buses

# %% [markdown]
# ### pie charts

# %%
plt.style.use('Solarize_Light2')
plt.pie(jr1['duration'].value_counts(),labels=jr1['duration'].unique(),autopct="%.1f")
plt.show()

# %% [raw]
# insights:
#     1.the buses which has 4 hrs duration they have 0.5 percentage
#     2.the buses which has 5 hrs duration they have 40.9 percentage
#     3.the buses which has 6 hrs duration they have 33.0 percentage
#     4.the buses which has 7 hrs duration they have 18.7 percentage
#     5.the buses which has 8 hrs duration they have 5.4 percentage
#     6.the buses which has 9 hrs duration they have 1.5 percentage

# %% [markdown]
# ### bivariate

# %% [markdown]
# ### Continous vs Categorical

# %% [markdown]
# ##### Average Ticket price bases on ac type

# %%
sns.catplot(data=jr1,x='AC_type',y='prices',kind='bar').set(title='Average Ticket price of buses on ac type')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of ac buse is 1000
#     2.average ticket price of non ac bus is 750

# %% [markdown]
# ##### Average Ticket price bases on sleeper

# %%
plt.style.use('classic')
sns.catplot(data=jr1,x='sleeper',y='prices',kind='bar').set(title='Average Ticket price buses on sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of sleeper bus is 1100
#     2.average ticket price of non sleeper  bus is 550

# %% [markdown]
# ##### Average Ticket price bases on semi_sleeper

# %%
plt.style.use('ggplot')
sns.catplot(data=jr1,x='semi_sleeper',y='prices',kind='bar').set(title='Average Ticket price bases on semi_sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of semi_sleeper bus is 700
#     2.average ticket price of non semi_sleeper  bus is 900

# %% [markdown]
# ##### Average Ticket price bases on seater

# %%
plt.style.use('ggplot')
sns.catplot(data=jr1,x='Seater',y='prices',kind='bar').set(title='Average Ticket price bases on seater')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of seater bus is 900
#     2.average ticket price of non seater bus is 1100

# %% [markdown]
# ## Categorical vs Categorical

# %% [markdown]
# ##### Top 5 AC travel bus names

# %%
pd.crosstab(jr1['Bus_Name'],jr1['AC_type']).sort_values('A/C',ascending=False).head()
# Out:
# AC_type                    A/C  NON A/C
# Bus_Name
# NueGo                       18        0
# Orange Tours And Travels    12       16
# FRESHBUS                    10        0
# IntrCity SmartBus            9        0
# Morning Star Travels         6        1

# %%
pd.crosstab(jr1['Bus_Name'],jr1['AC_type']).sort_values('A/C',ascending=False).head().plot(kind='bar').set(title='Top 5 AC travel bus names')
plt.show()

# %% [raw]
# insights:
#      1.There is are 18 a/c NueGo naming bus
#      2. orange tours and travel naming bus has 16 non a/c buses
#      3.there are 1 non a/c for morning star travels
#      4.NueGo,freshbusmintracity ,smartbus these 3 buses don't have non ac features

# %% [markdown]
# ##### Top 5 NON AC travel bus names

# %%
pd.crosstab(jr1['Bus_Name'],jr1['AC_type']).sort_values('NON A/C',ascending=False).head()
# Out:
# AC_type                    A/C  NON A/C
# Bus_Name
# Orange Tours And Travels    12       16
# Sri KVR Travels              1        6
# V Kaveri Travels             5        5
# KKaveri Travels              0        5
# Sai RK Travels               0        4

# %%
pd.crosstab(jr1['Bus_Name'],jr1['AC_type']).sort_values('NON A/C',ascending=False).head().plot(kind='bar').set(title='Top 5 NON AC travel bus names')
plt.show()

# %% [raw]
# insights:
#      1.there are 16 orange tours and travel buses those are non a/c and 12 buses are a/c
#      2.there are 2 sri kvr travels buses those are a/c and 6 buses are non a/c
#      3.there are 5 v kaveri travels buses those are a/c and also 5 buses those are non a/c
#      4.there are 5 kkaveri travels buses those are only a/c,it has no non a/c buses
#      5.there are only 1 jayanthi travels bus for a/c and 4 buses for non a/c

# %% [markdown]
# ##### A complete data of number of AC type and Seater type buses

# %%
s1=pd.crosstab(df['sleeper'],df['AC_type'])
s2=pd.crosstab(df['semi_sleeper'],df['AC_type'])
s3=pd.crosstab(df['Seater'],df['AC_type'])
s=pd.concat([s1,s2,s3],axis=0)
s.index = ['non sleeper', 'sleeper', 'non semi_sleeper', 'semi_sleeper', 'non seater', 'seater']

# %%
s
# Out:
# AC_type           A/C  NON A/C
# non sleeper        31        5
# sleeper            91       67
# non semi_sleeper  112       72
# semi_sleeper       10        0
# non seater         66        7
# seater             56       65

# %%
s.plot(kind='bar').set(title='A complete data of number of AC type and Seater type buses')
plt.show()

# %% [raw]
# insights:
#      1.there are nearly 121 buses those are a/c non semi sleeper
#      2.there are nearly 78 buses those are non a/c non semi sleeper
#      3.there are nearly 10 buses those are semi sleeper,it has a/c facility but there is no non a/c facility
#      4.there are nearly 30 buses those are non sleeper a/c buses but nearly 5 buses has non a/c for non sleeper
#      5.there are nearly 100 buses those are a/c with sleeper and nearly 70 buses for non ac sleeper

# %% [markdown]
# ##### Continous Vs Continous

# %% [markdown]
# #### Scatter plot based on price and ratings based on ac type

# %%
plt.style.use('ggplot')
sns.scatterplot(data=jr1,y='prices',x='ratings',hue='AC_type').set(title='Scatter plot based on price and ratings based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.In x and y axis it represents the continous values
#     2.there is only one bus with low cost and 4.8 star rating
#     3.there is only one bus with low cost and 4.7 star rating
#     4.only ac type buses has more rating and more prices
#     5.there are less ac buses with rating below 3.5

# %% [markdown]
# ###### Average ticket price of each travels

# %%
df1=df[(df['ratings']>4.5) & (df['prices']<700)].reset_index()
df1.drop('index',axis=1,inplace=True)
df1
# Out:
#                     Bus_Name                         Bus_type from   to  \
# 0         IntrCity SmartBus        A/C Seater / Sleeper (2+1)  HYD  VJY
# 1         IntrCity SmartBus        A/C Seater / Sleeper (2+1)  HYD  VJY
# 2                AdFRESHBUS         Electric A/C Seater (2+2)  HYD  VJY
# 3                     NueGo         Electric A/C Seater (2+2)  HYD  VJY
# 4                  FRESHBUS         Electric A/C Seater (2+2)  HYD  VJY
# 5                  FRESHBUS         Electric A/C Seater (2+2)  HYD  VJY
# 6                     NueGo   Electric A/C Semi Sleeper (2+2)  HYD  VJY
# 7                  FRESHBUS         Electric A/C Seater (2+2)  HYD  VJY
# 8                  FRESHBUS         Electric A/C Seater (2+2)  HYD  VJY
# 9                  FRESHBUS         Electric A/C Seater (2+2)  HYD  VJY
# 10      Sri  Atluri Travels             NON A/C Hi-Tech (2+2)  HYD  VJY
# 11                    NueGo   Electric A/C Semi Sleeper (2+2)  HYD  VJY
# ...

# %%
df1.groupby('Bus_Name')['prices'].mean().plot(kind='bar').set(title='Average ticket price of each travels')
plt.show()

# %% [raw]
# insights:
#     1.adfreshbus  buses has avg ticket price is 490
#     2.freshbus buses has avg ticket price is 450
#     3.intrcity smartbus buses has avg ticket price is 650
#     4.nuego buses has avg ticket price is 510
#     5.pavan tours and travels bues has avg ticket price is 700
#     6.sri atluri travels buses has avg ticket price is 550

# %% [markdown]
# ##### Scatter plot based on price and duration based on ac type

# %%
plt.style.use('ggplot')
sns.scatterplot(data=jr1,y='prices',x='duration',hue='AC_type').set(title='Scatter plot based on price and duration based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.there is only one ac bus with 4 hr duration
#     2.there are 2 non ac buses with 4hr duration
#     3.price of 1 non ac bus with 4 hr duration is approx 700
#     4.there are less buses with more than 7 hr duration

# %% [markdown]
# ###### Bus names and ticket prices of fast buses

# %%
df2=df[df['duration']<5]
df2.reset_index()
df2.reset_index(drop = True,inplace =True)
df2.set_index('Bus_Name',inplace=True)
df2.plot(kind = 'bar').set(title="Bus names and ticket prices of fast buses")
plt.show()

# %% [raw]
# insights:
#     1.sai rk travels buses has  ticket price is 650
#     2.sri kvr travels buses has  ticket price is 1500
#     3.intracity smartbus has ticket price is above 1400
#     3.these 3 buses are fast than among all buses

# %% [markdown]
# ## Multivariate

# %% [markdown]
# ### Heatmap

# %% [markdown]
# ##### Heatmap on buses dataser

# %%
sns.heatmap(jr1.corr(numeric_only=True),annot=True).set(title='Scatter plot based on price and ratings based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.there is +ve moderate relationship between prices and duration its correlation coefficient is 0.035
#     2.there is +ve moderate relationship between ratings and duration its correlation coefficient is 0.0046
#     3.there is _ve very strong relationship between prices and ratings its correlation coefficient is -0.16

# %% [markdown]
# ### pairplot

# %%
sns.pairplot(jr1,hue='AC_type')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(jr1,hue='Seater')
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(jr1,hue='sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(jr1,hue='semi_sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
