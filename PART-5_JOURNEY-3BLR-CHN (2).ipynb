# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('jr3.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
jr3=df

# %%
jr3
# Out:
#                  Bus_Name                                      Bus_type from  \
# 0        KMRL Kalaimakal                     A/C Seater / Sleeper (2+1)  BLR
# 1            V2K Travels                              A/C Sleeper (2+1)  BLR
# 2        Jabbar  Travels   Volvo A/C B11R Multi Axle Semi Sleeper (2+2)  BLR
# 3    AdIntrCity SmartBus                     A/C Seater / Sleeper (2+1)  BLR
# 4        KMRL Kalaimakal                              A/C Sleeper (2+1)  BLR
# ..                    ...                                           ...  ...
# 128    National  travels                              A/C Sleeper (2+1)  BLR
# 129    National  travels                              A/C Sleeper (2+1)  BLR
# 130     Starlink Travels                              A/C Sleeper (2+1)  BLR
# 131          VJS Travels                  Bharat Benz A/C Sleeper (2+1)  BLR
# 132          RDS Travels                  Scania A/C Semi Sleeper (2+2)  BLR
#
# ...

# %% [markdown]
# ### Histogram

# %% [markdown]
# ##### Prices of bustickets of BLR TO CHN

# %%
plt.figure(figsize=(8,3))
plt.hist(df['prices'],bins=10,color='purple')
plt.xlabel("Prices")
plt.ylabel("Frequency")
plt.title("Histogram of prices")
plt.show()

# %% [raw]
# insights:
#     1.blr to chn busticket prices ranges from 400 to 1600
#     2.there is 63 buses those ticket price ranges from 750 to 900
#     3.there is nearly 58 buses those ticket price ranges from 400 to 750
#     4.there is 5 nearly 5 buses those ticket prices ranges from 900 to 1100

# %% [markdown]
# ##### Ratings of bustickets from BLR to CHN

# %%
plt.figure(figsize=(6,3))
plt.hist(df['ratings'],bins=10,color='red')
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.title("Histogram of ratings")
plt.show()

# %% [raw]
# insights:
#     1.there is nearly 38 buses those ratings ranges from 4.3 to 4.5
#     2. there is nearly 16 buses those ratings ranges from 3.5 to 4.0
#     3.there is nearly 8 buses those ratings ranges from 3.3 to 3.5
#     4.there is nearly 5 buses those ratings ranges from 3.0 to 3.5

# %% [markdown]
# ### Density plot

# %% [markdown]
# ##### Prices of bustickets based on AC_type

# %%
plt.style.use('dark_background')
sns.histplot(data=df,x='prices',bins=20,color='red',hue='AC_type',kde=True).set(title='Prices of bustickets based on AC_type')
plt.show()

# %% [raw]
# insights:
#     1.a/c bus ticket prices ranges between 500 to 1500
#     2.non a/c bus ticket prices ranges between 500 to 1000
#     3.there are only ac buses above 1000
#     4.there nearly 41 ac buses those has approxemately 800 ticket price
#     5.there is 5 non ac buses those has below 500 bus ticket price

# %% [markdown]
# ##### density plot for duration and prices

# %%
plt.style.use('dark_background')
sns.kdeplot(data=df,x='prices',color='red',hue='duration').set(title='density plot for duration and prices')
plt.show()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_4156\845247886.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df,x='prices',color='red',hue='duration').set(title='density plot for duration and prices')

# %% [markdown]
# ##### Prices of bustickets based on sleeper

# %%
sns.set_style('dark')
sns.histplot(data=df,x='prices',bins=20,color='red',hue='sleeper',kde=True).set(title='Prices of bustickets based on sleeper')
plt.show()

# %% [raw]
# insights:
#     1.sleeper bus ticket prices ranges between 500 to 1500
#     2.non sleeper ticket prices ranges between 500 to 1100
#     3.there are nearly 38 sleeper buses those ticket price aproxemately 800
#     4.there are 6 non sleeper buses those has ticket price has less than 500

# %% [markdown]
# ##### Prices of bustickets based on seater

# %%
plt.style.use('classic')
sns.histplot(data=jr3,x='prices',bins=20,color='red',hue='Seater',kde=True).set(title='Prices of bustickets based on seater')
plt.show()

# %% [raw]
# insights:
#     1.seater bus ticket prices ranges between 500 to 1000
#     2.non seater ticket prices ranges between 500 to 1500
#     3.there are only non seater buses above 1000
#     4.there are 38 buses those has aproxemately ticket price 600

# %% [markdown]
# ##### Prices of bustickets based on semi_seater

# %%
sns.set_style('darkgrid')
sns.histplot(data=jr3,x='prices',bins=20,color='purple',hue='semi_sleeper',kde=True).set(title='Prices of bustickets based on semi_seater')
plt.show()

# %% [raw]
# insights:
#     1.for non semi sleeper the ticket price ranges from 500 to 1500
#     2.for semi sleeper the ticket price ranges from 500 to 100
#     3.there are nearly 13 non sleeper buses whose ticket price is below 500
#     4.there are nearly 3 buses those has ticket price is below 500

# %% [markdown]
# ##### Prices of bustickets based on seater

# %%
plt.style.use('dark_background')
sns.histplot(data=jr3,x='ratings',bins=20,color='red',hue='Seater',kde=True).set(title='Prices of bustickets based on seater')
plt.show()

# %% [raw]
# insights:
#     1.there are 20 or more than 20 non seater buses those has max 4.5 ratings
#     2.there are nearly 16 non seater buses those ratings ranges from 4.0 to 4.2
#     3.there are nearly 13 non seater  buses those ratings is 4.3
#     4.there are 10 non seater buses those has 4.6 rating
#     5.there are 8 seater buses those has 4.1 ratings
#     6.there are 6 seater buses those has 4.0 ratings

# %% [markdown]
# ### box plot

# %% [markdown]
# ##### outliers of ticket Prices based on AC_type  & sleeper

# %%
sns.set_style('darkgrid')
sns.boxplot(data=jr3,y='prices',x='sleeper',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & sleeper')
plt.show()

# %% [raw]
# insights:
#     1.there are 5 outliers in ac sleeper buses
#     2.there is 1 outlier for non ac  sleeper bus
#     3.there are no buses  for non ac non sleeper
#     4.there are no outliers for ac non sleeper buses

# %% [markdown]
# ##### Outliers of ticket Prices based on AC_type & seater

# %%
plt.style.use('ggplot')
sns.boxplot(data=jr3,y='prices',x='Seater',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & seater')
plt.show()

# %% [raw]
# insights:
#     1.there are no outliers for seater buses
#     2.there are 4 outliers for ac non seater buses
#     3.there is one outlier in non ac non seater buses

# %% [markdown]
# ##### Outliers of ticket Prices based on AC_type & semi sleeper

# %%
sns.set_style('whitegrid')
sns.boxplot(data=jr3,y='prices',x='semi_sleeper',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & semi sleeper')
plt.show()

# %% [raw]
# insights:
#     1.there are 5 outliers in ac non semi_sleeper buses
#     2.there is 2 outlier for non ac non semi sleeper buses
#     3.there are no outliers in non ac  semi_sleeper
#     3.there no buses of non ac semi sleeper

# %% [markdown]
# ### line chart

# %% [markdown]
# ##### Line chart for duration and prices

# %%
sns.lineplot(data=jr3,x='duration',y='prices',estimator='sum').set(title='Line chart for duration and prices')
plt.show()

# %% [raw]
# insights:
#     1.6hr duration buses has more ticket price.
#     2.duration increases price decrease.

# %% [markdown]
# ##### Line chart for ratings and prices

# %%
sns.lineplot(data=jr3,x='ratings',y='prices',estimator='sum').set(title='Line chart for ratings and prices')
plt.show()

# %% [raw]
# insights:
#     1.ratings is proportional to price
#     2.high rating buses has high prices
#     3.low rating buses has low prices

# %% [markdown]
# ## Categorical

# %% [markdown]
# ### count plot

# %% [markdown]
# ##### Count of number of ac buses

# %%
sns.set_style('white')
plt.figure(figsize=(2,1))
sns.catplot(data=jr3,x='AC_type',kind='count').set(title='Count of number of ac buses')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['AC_type'].value_counts()
# Out:
# AC_type
# A/C        124
# NON A/C      9
# Name: count, dtype: int64

# %% [raw]
# insights:
#      1.there is 123 a/c buses
#      2.there is 8 non a/c buses

# %% [markdown]
# ##### Count of number of seater

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(4,3))
sns.countplot(data=jr3,x='Seater').set(title='Count of number of seater')
plt.show()

# %%
df['Seater'].value_counts()
# Out:
# Seater
# no     107
# yes     26
# Name: count, dtype: int64

# %% [raw]
# insights:
#      1.there 105 non seater buses
#      2.there is 26 seater buses

# %% [markdown]
# ##### Count of number of sleeper

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=jr3,x='sleeper').set(title='Count of number of sleeper')
plt.show()

# %%
df['sleeper'].value_counts()
# Out:
# sleeper
# yes    110
# no      23
# Name: count, dtype: int64

# %% [raw]
# insights:
#       1.there is 109 sleeper buses
#       2.there is 22 non sleeper buses

# %% [markdown]
# ##### Count of number of semi sleeper

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=jr3,x='semi_sleeper').set(title='Count of number of semi sleeper')
plt.show()

# %%
df['semi_sleeper'].value_counts()
# Out:
# semi_sleeper
# no     121
# yes     12
# Name: count, dtype: int64

# %% [raw]
# insights:
#     1.there is 119 non sleeper buses
#     2.there is 12 sleeper buses

# %% [markdown]
# ### pie charts

# %%
plt.style.use('Solarize_Light2')
plt.pie(jr3['duration'].value_counts(),labels=jr3['duration'].unique(),autopct="%.1f")
plt.show()

# %% [raw]
# insights:
#       1.those buses has 5 hrs duration they has 7.6 percentage
#       2.those buses has 6 hrs duration they has 57.3 percentage
#       3.those buses has 7 hrs duration they has 34.4 percentage
#       4.those buses has 8 hrs duration they has 0.8 percentage

# %% [markdown]
# ### bivariate

# %% [markdown]
# ### Continous vs Categorical

# %% [markdown]
# ##### Average Ticket price bases on ac type

# %%
sns.catplot(data=jr3,x='AC_type',y='prices',kind='bar').set(title='Average Ticket price of buses on ac type')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of ac buses is 710
#     2.average ticket price of non ac buses is 610

# %% [markdown]
# ##### Average Ticket price bases on sleeper

# %%
plt.style.use('classic')
sns.catplot(data=jr3,x='sleeper',y='prices',kind='bar').set(title='Average Ticket price buses on sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of sleeper bus is 710
#     2.average ticket price of non sleeper  bus is 600

# %% [markdown]
# ##### Average Ticket price bases on semi_sleeper

# %%
plt.style.use('ggplot')
sns.catplot(data=jr3,x='semi_sleeper',y='prices',kind='bar').set(title='Average Ticket price bases on semi_sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of semi_sleeper bus is 610
#     2.average ticket price of non semi_sleeper  bus is 720

# %% [markdown]
# ##### Average Ticket price bases on seater

# %%
plt.style.use('ggplot')
sns.catplot(data=jr3,x='Seater',y='prices',kind='bar').set(title='Average Ticket price bases on seater')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of seater bus is 590
#     2.average ticket price of non seater bus is 750

# %% [markdown]
# ## Categorical vs Categorical

# %% [markdown]
# ##### Top 5 AC travel bus names

# %%
pd.crosstab(jr3['Bus_Name'],jr3['AC_type']).sort_values('A/C',ascending=False).head()
# Out:
# AC_type             A/C  NON A/C
# Bus_Name
# NueGo                14        0
# IntrCity SmartBus    14        0
# Bharathi  Travels     7        0
# Jabbar  Travels       7        0
# SPS Travels           6        0

# %%
pd.crosstab(jr3['Bus_Name'],jr3['AC_type']).sort_values('A/C',ascending=False).head().plot(kind='bar').set(title='Top 5 AC travel bus names')
plt.show()

# %% [raw]
# insights:
#      1.there are 14 a/c incity smartbuses
#      2.there are also 14 a/c NueGo buses
#      3.there are 7 a/c bharathi travels buses
#      4.there are also 7 a/c jabbar travels buses
#      5.there are 6 a/c national travels buses and 2 non a/c buses

# %% [markdown]
# ##### Top 5 NON AC travel bus names

# %%
pd.crosstab(jr3['Bus_Name'],jr3['AC_type']).sort_values('NON A/C',ascending=False).head()
# Out:
# AC_type                A/C  NON A/C
# Bus_Name
# National  travels        6        2
# KGN INDIA                0        2
# Sharma Transports        1        1
# NATIONAL TRAVELS NTA     4        1
# KPN Travels              0        1

# %%
pd.crosstab(jr3['Bus_Name'],jr3['AC_type']).sort_values('NON A/C',ascending=False).head().plot(kind='bar').set(title='Top 5 NON AC travel bus names')
plt.show()

# %% [raw]
# insights:
#     1.there are 6 a/c and 2 non a/c National travel buses
#     2.there are 2 non a/c KGN India buses
#     3.there each 1 a/c and non a/c sharma transport buses
#     4.there are 4 a/c and 1 non a/c National travels nta buses
#     5.there is only 1 non a/c bus for kpn travels

# %% [markdown]
# ##### A complete data of number of AC type and Seater type buses

# %%
s1=pd.crosstab(df['sleeper'],df['AC_type'])
s2=pd.crosstab(df['semi_sleeper'],df['AC_type'])
s3=pd.crosstab(df['Seater'],df['AC_type'])
s=pd.concat([s1,s2,s3],axis=0)
s.index = ['non sleeper', 'sleeper', 'non semi_sleeper', 'semi_sleeper', 'non seater', 'seater']

# %%
s
# Out:
# AC_type           A/C  NON A/C
# non sleeper        22        1
# sleeper           102        8
# non semi_sleeper  112        9
# semi_sleeper       12        0
# non seater        100        7
# seater             24        2

# %%
s.plot(kind='bar').set(title='A complete data of number of AC type and Seater type buses')
plt.show()

# %% [raw]
# insights:
#     1.there are 21 a/c non sleeper and 1 non ac non sleeper bus
#     2.there are 101 a/c and 8 non ac sleeper buses
#     3.there are 110 a/c and 8 non a/c  non semi sleeper buses
#     4.there are 10 non a/c semi sleeper buses
#     5.there are 99 a/c and 6 non a/c non seater buses
#     6.there are 22 a/c and 2 non a/c seater buses

# %% [markdown]
# ##### Continous Vs Continous

# %% [markdown]
# #### Scatter plot based on price and ratings based on ac type

# %%
plt.style.use('ggplot')
sns.scatterplot(data=jr3,y='prices',x='ratings',hue='AC_type').set(title='Scatter plot based on price and ratings based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.there is only 1 ac bus with 4.7 ratting
#     2.there are less ac buses with price more than 1000
#     3.there is only one non ac bus with 4.4
#     4.there are only 2ac buses with less price

# %%
df2=df[(df['ratings']>4.5)&(df['prices']<1000)].reset_index()
df2.drop('index',axis=1,inplace=True)
df2
# Out:
#               Bus_Name                                      Bus_type from  \
# 0     KMRL Kalaimakal                     A/C Seater / Sleeper (2+1)  BLR
# 1         V2K Travels                              A/C Sleeper (2+1)  BLR
# 2     Jabbar  Travels   Volvo A/C B11R Multi Axle Semi Sleeper (2+2)  BLR
# 3     KMRL Kalaimakal                              A/C Sleeper (2+1)  BLR
# 4   IntrCity SmartBus                     A/C Seater / Sleeper (2+1)  BLR
# 5     KMRL Kalaimakal                              A/C Sleeper (2+1)  BLR
# 6         SPS Travels                              A/C Sleeper (2+1)  BLR
# 7     Jabbar  Travels                           VE A/C Sleeper (2+1)  BLR
# 8   IntrCity SmartBus                               AC Sleeper (2+1)  BLR
# 9       NWAY HOLIDAYS                              A/C Sleeper (2+1)  BLR
# 10        KBS Travels                              A/C Sleeper (2+1)  BLR
# 11        KBS Travels                              A/C Sleeper (2+1)  BLR
#
# ...

# %%
df2.groupby('Bus_Name')['prices'].mean().plot(kind='bar').set(title='Average ticket prices of bus names with more ratings and price below 1000')
plt.show()

# %% [raw]
# insights:
#      1.intracity smartbus buses has avg ticket price is above 600
#      2.jabbar travel buses has avg ticket price is above 510
#      3.kbs travels buses has avg ticket price is above 710
#      4.kmrl kalamakal buses has avg ticket price is above 750
#      5.nway holidays buses has avg ticket price is above 690
#      6.sps buses has avg ticket price is above 790
#      7.v2k  buses has avg ticket price is above 800

# %% [markdown]
# ##### Scatter plot based on price and duration based on ac type

# %%
sns.scatterplot(data=jr3,x='duration',y='prices',hue='AC_type').set(title='Scatter plot based on price and duration based on ac type')
plt.show()

# %% [raw]
# insights:
#      1.there are only 4 buses with 5 hr duraton
#      2.there is only one bus which takes more time around 8 hr
#      3.there are 3 buses with price less than 500

# %% [markdown]
# ###### average prices of less duration buses

# %%
df3=df[df['duration']<5.5].reset_index()
df3.drop('index',axis=1,inplace=True)
df3
# Out:
#                            Bus_Name  \
# 0  GreenLine Travels And  Holidays
# 1                      RKK Travels
# 2                      VKV Travels
# 3            Swamy Ayyappa Travels
# 4                  Jabbar  Travels
# 5                  Parveen Travels
# 6                Bharathi  Travels
# 7                    Vetri Travels
# 8                Bharathi  Travels
# 9                      VJS Travels
#
#                                        Bus_type from   to pickup_time  \
# 0                          VE A/C Sleeper (2+1)  BLR  CHN       23:15
# 1       Volvo Multi-Axle A/C Semi Sleeper (2+2)  BLR  CHN       04:00
# 2                             A/C Sleeper (2+1)  BLR  CHN       01:35
# 3                             A/C Sleeper (2+1)  BLR  CHN       23:30
# 4                             A/C Sleeper (2+1)  BLR  CHN       23:20
# 5  Volvo A/C B11R Multi Axle Semi Sleeper (2+2)  BLR  CHN       05:25
# 6                             A/C Sleeper (2+1)  BLR  CHN       01:25
# ...

# %%
df3.groupby('Bus_Name')['prices'].mean().plot(kind='bar').set(title='average prices of less duration buses')
plt.show()

# %% [raw]
# insights:
#     1.Bharathi buses has the avg price of less duration is 650
#     2.greenline travels and holidays buses has the avg price of less duration is 900
#     3.jabbara travels buses has the avg price of less duration is 610
#     4.parveen travels buses has the avg price of less duration is 610
#     5.rkk travels buses has the avg price of less duration is 590
#     6.swamy ayyappa travels buses has the avg price of less duration is 800
#     7.vjs travels buses has the avg price of less duration is 700
#     8.vkv travels buses has the avg price of less duration is 1390
#     9.vetri travels buses has the avg price of less duration is 620

# %% [markdown]
# ## Multivariate

# %% [markdown]
# ### Heatmap

# %% [markdown]
# ##### Heatmap on buses dataser

# %%
sns.heatmap(jr3.corr(numeric_only=True),annot=True).set(title='Scatter plot based on price and ratings based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.the relationship between duration and ratings is positive,very weak relationship,the corelation coeficient is 0.11
#     2.the relationship between duration and prices is negative ,very weak relationship,the corelation coeficient is -0.2
#     3.the relationship between prices and ratings is negative,strong relationship,the corelation coeficient is -0.0071

# %% [markdown]
# ### pairplot

# %%
sns.pairplot(jr3,hue='AC_type')
plt.show()

# %%
sns.pairplot(jr3,hue='Seater')

# %%
sns.pairplot(jr3,hue='sleeper')
plt.show()

# %%
sns.pairplot(jr3,hue='semi_sleeper')
plt.show()
