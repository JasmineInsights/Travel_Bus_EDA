# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('jr2.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Bus_Name         object
# Bus_type         object
# from             object
# to               object
# pickup_time      object
# drop_time        object
# duration          int64
# prices            int64
# ratings         float64
# AC_type          object
# Seater           object
# semi_sleeper     object
# sleeper          object
# dtype: object

# %%
jr2=df

# %%
jr2
# Out:
#                    Bus_Name                                 Bus_type from  \
# 0             KSM Roadways   A/C Volvo B11R Multi-Axle Sleeper (2+1)  HYD
# 1    VSR Tours and Travels                         A/C Sleeper (2+1)  HYD
# 2          Jabbar  Travels        Scania AC Multi Axle Sleeper (2+1)  HYD
# 3       AdNovember Travels                A/C Seater / Sleeper (2+1)  HYD
# 4          Jabbar  Travels                      VE A/C Sleeper (2+1)  HYD
# ..                      ...                                      ...  ...
# 168            VRL Travels                     NON A/C Sleeper (2+1)  HYD
# 169            VRL Travels   Volvo 9600 Multi-Axle A/C Sleeper (2+1)  HYD
# 170            VRL Travels                         A/C Sleeper (2+1)  HYD
# 171            VRL Travels                         A/C Sleeper (2+1)  HYD
# 172            VRL Travels                     NON A/C Sleeper (2+1)  HYD
#
#       to pickup_time drop_time  duration  prices  ratings  AC_type Seater  \
# ...

# %% [markdown]
# ### Histogram

# %% [markdown]
# ##### Prices of bustickets of HYD TO BLR

# %%
plt.figure(figsize=(8,3))
plt.hist(df['prices'],bins=10,color='purple')
plt.xlabel("Prices")
plt.ylabel("Frequency")
plt.title("Histogram of prices")
plt.show()

# %% [raw]
# insights:
#     1.hyd to blr busticket prices ranges from 400 to 3500
#     2.there is 72 buses those price ranges from 1000-1500
#     3.There are nearly 5 buses whose price  is 2000
#     4.there nearly 58 buses whose ticket price is 1000
#     5.there is nearly 30 buses whose bus ticket price ranges from 1500 to 2000

# %% [markdown]
# ##### Ratings of bustickets from HYD TO BLR

# %%
plt.figure(figsize=(6,3))
plt.hist(df['ratings'],bins=10,color='red')
plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.title("Histogram of ratings")
plt.show()

# %% [raw]
# insights:
#     1.Rating ranges between 1.0 and 5.0
#     2.significant number of buses are been rated with a 4.5 star rating
#     3.very few buses got 2.0 star rating
#     4.there is nearly 44 buses who has 4.5 ratings
#     5.there is nearly 20 buses who has 5.0 ratings
#     6.there is nearly 23 buses who has 4.0 ratings
#     7.there is 20 buses whose ratings ranges from 3.0 to 3.5

# %% [markdown]
# ### Density plot

# %% [markdown]
# ##### Prices of bustickets based on AC_type

# %%
plt.style.use('dark_background')
sns.histplot(data=df,x='prices',bins=20,color='red',hue='AC_type',kde=True).set(title='Prices of bustickets based on AC_type')
plt.show()

# %% [raw]
# insights:
#     1.a/c bus ticket prices ranges between 500 to 3000
#     2.non a/c bus ticket prices ranges between 500 to 1800
#     3.there are maximum ac buses prices above 1000
#     4.there is nearly 30 buses those has bus ticket price aproxemately 900
#     5.there is nearly 3 buses those has ticket price 3000

# %% [markdown]
# ##### Density plot for duration

# %%
plt.style.use('dark_background')
sns.kdeplot(data=df,x='prices',color='red',hue='duration').set(title='Density plot for duration')
plt.show()

# %% [markdown]
# ##### Prices of bustickets based on sleeper

# %%
sns.set_style('dark')
sns.histplot(data=df,x='prices',bins=20,color='red',hue='sleeper',kde=True).set(title='Prices of bustickets based on sleeper')
plt.show()

# %% [raw]
# insights:
#     1.sleeper bus ticket prices ranges between 500 to 3000
#     2.non sleeper ticket prices ranges between 500 to 1000
#     3.there are only sleeper buses has above 1000 ticket price
#     4.there is more than 40 buses those has aproxemately 1100 price
#     5.there is nearly 15 buses those has aproxemately ticket price 900

# %% [markdown]
# ##### Prices of bustickets based on seater

# %%
plt.style.use('classic')
sns.histplot(data=jr2,x='prices',bins=20,color='red',hue='Seater',kde=True).set(title='Prices of bustickets based on seater')
plt.show()

# %% [raw]
# insights:
#     1.seater bus ticket prices ranges between 500 to 2500
#     2.non seater ticket prices ranges between 500 to 1600
#     3.there is 15 seater buses those ticket price ranges from aproxdemately 600 to 900
#     4.more than 40 non seater has price ranges aproxemately 1100 ticket price
#     5.there is nearly 11 buses those ticket price ranges from aproxemately 1600 to 1800
#     6.there is nearly 29 non seater buses those ticket price aproxemately 900

# %% [markdown]
# ##### Prices of bustickets based on semi_seater

# %%
sns.set_style('darkgrid')
sns.histplot(data=jr2,x='prices',bins=20,color='purple',hue='semi_sleeper',kde=True).set(title='Prices of bustickets based on semi_seater')
plt.show()

# %% [raw]
# insights:
#     1.semi sleeper bus ticket prices ranges between 500 to 1100
#     2.non semi sleeper ticket prices ranges between 500 to 3000
#     3.there is more than non sleeper buses those has aproxemately 1100 ticket price.
#     4.there is 4 semi slepeer buses those has ticket price 500 and 1000
#     5.there is very few buses those price ranges from 2000 to 2500

# %% [markdown]
# ##### Prices of bustickets based on seater

# %%
plt.style.use('ggplot')
sns.histplot(data=jr2,x='ratings',bins=20,color='red',hue='Seater').set(title='Prices of bustickets based on seater')
plt.show()

# %% [raw]
# insigts:
#     1.there is non seater buses has higest ratings than seater buses
#     2.there is 20 non seater buses those has 4.5 ratings
#     3.there is more than 16 non seater buses those ratings ranges from 4.5 to 5.0
#     4.but there is 5 or less than 5 seater buses those has ratings

# %% [markdown]
# ### box plot

# %% [markdown]
# ##### outliers of ticket Prices based on AC_type  & sleeper

# %%
sns.set_style('darkgrid')
sns.boxplot(data=jr2,y='prices',x='sleeper',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & sleeper')
plt.show()

# %% [raw]
# insights:
#     1.there are 4 outliers in a/c and sleeper buses
#     2.there is 1 outlier for  non a/c and sleeper bus
#     3.there are no outliers for non ac and non sleeper and  ac and non sleeper buses

# %% [markdown]
# ##### Outliers of ticket Prices based on AC_type & seater

# %%
plt.style.use('ggplot')
sns.boxplot(data=jr2,y='prices',x='Seater',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & seater')
plt.show()

# %% [raw]
# insights:
#     1.there are 4 outliers in ac and non seater buses
#     2.there is 1 outliers in non ac and non seater buses
#     3.there are 1 outliers in  ac and seater buses
#     4.there are no outliers in non ac and  seater buses

# %% [markdown]
# ##### Outliers of ticket Prices based on AC_type & semi sleeper

# %%
sns.set_style('whitegrid')
sns.boxplot(data=jr2,y='prices',x='semi_sleeper',hue='AC_type',orient='v').set(title='Outliers of ticket Prices based on AC_type & semi sleeper')
plt.show()

# %% [raw]
# insights:
#     1.there are 4 outliers in ac and non semi_sleeper buses
#     2.there is 1 outlier for non ac and non semi seater buses
#     3.there are no outliers in  ac and semi_sleeper buses
#     3.there no buses of non ac and semi sleeper buses

# %% [markdown]
# ### line chart

# %% [markdown]
# ##### Line chart for ratings and prices

# %%
sns.lineplot(data=jr2,x='ratings',y='prices',estimator='sum').set(title='Line chart for ratings and prices')
plt.show()

# %% [raw]
# insights:
#     1.ratings is proportional to price
#     2.high rating buses has high prices
#     3.low rating buses has low prices

# %% [markdown]
# ## Categorical

# %% [markdown]
# ### count plot

# %% [markdown]
# ##### Count of number of ac buses

# %%
sns.set_style('white')
plt.figure(figsize=(2,1))
sns.catplot(data=jr2,x='AC_type',kind='count').set(title='Count of number of ac buses')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['AC_type'].value_counts()
# Out:
# AC_type
# A/C        150
# NON A/C     23
# Name: count, dtype: int64

# %% [raw]
# insights:
#     1.there is 159 a/c buses
#     2.there is 14 non a/c buses

# %% [markdown]
# ##### Count of number of seater

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(4,3))
sns.countplot(data=jr2,x='Seater').set(title='Count of number of seater')
plt.show()

# %%
df['Seater'].value_counts()
# Out:
# Seater
# no     144
# yes     29
# Name: count, dtype: int64

# %% [raw]
# insights:
#     1.there is 144 non seater buses
#     2.there is 29 seater buses

# %% [markdown]
# ##### Count of number of sleeper

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=jr2,x='sleeper').set(title='Count of number of sleeper')
plt.show()

# %%
df['sleeper'].value_counts()
# Out:
# sleeper
# yes    160
# no      13
# Name: count, dtype: int64

# %% [raw]
# insights:
#     1.there is 161 non semi sleeper buses
#     2.there is 12 semi sleeper buses

# %% [markdown]
# ##### Count of number of semi sleeper

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=jr2,x='semi_sleeper').set(title='Count of number of semi sleeper')
plt.show()

# %%
df['sleeper'].value_counts()
# Out:
# sleeper
# yes    160
# no      13
# Name: count, dtype: int64

# %% [raw]
# insights:
#       1.there is 161 sleeper buses
#       2.there is 12 non sleeper buses

# %% [markdown]
# ### pie charts

# %%
plt.style.use('Solarize_Light2')
plt.pie(jr2['duration'].value_counts(),labels=jr2['duration'].unique(),autopct="%.1f")
plt.show()

# %% [raw]
# insights:
#     1.those buses has 12 hrs duration they has 6.9 percentage
#     2.those buses has 11 hrs duration they has 12.7 percentage
#     3.those buses has 10 hrs duration they has 34.1 percentage
#     4.those buses has 9 hr duration they has 39.3 percentage
#     5.those buses has 8 hr duration they has 5.8 percentage
#     6.those buses has 7 hr duration they has 1.2 percentage

# %% [markdown]
# ### bivariate

# %% [markdown]
# ### Continous vs Categorical

# %% [markdown]
# ##### Average Ticket price bases on ac type

# %%
sns.catplot(data=jr2,x='AC_type',y='prices',kind='bar').set(title='Average Ticket price of buses on ac type')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of ac buses is 1300
#     2.average ticket price of non ac bus is 900

# %% [markdown]
# ##### Average Ticket price bases on sleeper

# %%
plt.style.use('classic')
sns.catplot(data=jr2,x='sleeper',y='prices',kind='bar').set(title='Average Ticket price buses on sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of sleeper bus is 1300
#     2.average ticket price of non sleeper  bus is 800

# %% [markdown]
# ##### Average Ticket price bases on semi_sleeper

# %%
plt.style.use('ggplot')
sns.catplot(data=jr2,x='semi_sleeper',y='prices',kind='bar').set(title='Average Ticket price bases on semi_sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of semi_sleeper bus is 810
#     2.average ticket price of non semi_sleeper  bus is 1300

# %% [markdown]
# ##### Average Ticket price bases on seater

# %%
plt.style.use('ggplot')
sns.catplot(data=jr2,x='Seater',y='prices',kind='bar').set(title='Average Ticket price bases on seater')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# insights:
#     1.average ticket price of seater bus is 1000
#     2.average ticket price of non seater bus is 1300

# %% [markdown]
# ## Categorical vs Categorical

# %% [markdown]
# ##### Top 5 AC travel bus names

# %%
pd.crosstab(jr2['Bus_Name'],jr2['AC_type']).sort_values('A/C',ascending=False).head()
# Out:
# AC_type                            A/C  NON A/C
# Bus_Name
# Orange Tours And Travels            12        2
# IntrCity SmartBus                   12        0
# Morning Star Travels                 7        0
# Northern Travels                     7        0
# Kallada Travels (Suresh Kallada)     7        0

# %%
pd.crosstab(jr2['Bus_Name'],jr2['AC_type']).sort_values('A/C',ascending=False).head().plot(kind='bar').set(title='Top 5 NON AC travel bus names')
plt.show()

# %% [raw]
# insights:
#      1.there are 12 InCity smartbuses those has a/c facility but it don't has non a/c facility
#      2.there are 12 orange tours and travels buses those are a/c and 2 buses those are non a/c
#      3.there are 7 morning start travels buses those are a/c facility but it don't has non a/c facility
#      4.there are each 7 northen travels buses and kallada travel buses those has a/c facility but
#      they don't has non a/c facility

# %% [markdown]
# ##### Top 5 NON AC travel bus names

# %%
pd.crosstab(jr2['Bus_Name'],jr2['AC_type']).sort_values('NON A/C',ascending=False).head()
# Out:
# AC_type                 A/C  NON A/C
# Bus_Name
# Saleem Travels            0        2
# VRL Travels               3        2
# AVM Tours And Travels     0        2
# Kaleswari Travels         0        2
# GEE PEE TRAVELS           1        2

# %%
pd.crosstab(jr2['Bus_Name'],jr2['AC_type']).sort_values('NON A/C',ascending=False).head().plot(kind='bar').set(title='Top 5 NON AC travel bus names')
plt.show()

# %% [raw]
# insights:
#      1.orange tours and travels has  12 a/c and 2 non a/c buses
#      2.kaleswari travels has  2 non a/c buses,it don't has a/c buses
#      3.saleem travels has 2 non a/c buses it don't has a/c buses
#      4.avm tours and travels has 2 non a/c buses but it don't has a/c buses
#      5.gee pee travels has 1 a/c bus and 2 non a/c buses

# %% [markdown]
# ##### A complete data of number of AC type and Seater type buses

# %%
s1=pd.crosstab(df['sleeper'],df['AC_type'])
s2=pd.crosstab(df['semi_sleeper'],df['AC_type'])
s3=pd.crosstab(df['Seater'],df['AC_type'])
s=pd.concat([s1,s2,s3],axis=0)
s.index = ['non sleeper', 'sleeper', 'non semi_sleeper', 'semi_sleeper', 'non seater', 'seater']

# %%
s
# Out:
# AC_type           A/C  NON A/C
# non sleeper        10        3
# sleeper           140       20
# non semi_sleeper  140       21
# semi_sleeper       10        2
# non seater        133       11
# seater             17       12

# %%
s.plot(kind='bar').set(title='A complete data of number of AC type and Seater type buses')
plt.show()

# %% [raw]
# insights:
#      1.there are 10 a/c non sleeper buses
#      2.there 5 non a/c non sleeper buses
#      3.there are 140 a/c sleeper and 20 non a/c sleeper buses
#      4.there are 140 a/c non semi sleeper and 21 non a/c semi sleeper buses
#      5.there are 10 a/c semi sleeper and 3 non a/c semi sleeper buses
#      6.there nearly 135 a/c buses for non seater and 10 non a/c buses also
#      7.there are nearly 18 a/c buses for seater and 8 non a/c buses also

# %% [markdown]
# ##### Continous Vs Continous

# %% [markdown]
# #### Scatter plot based on price and ratings based on ac type

# %%
plt.style.use('ggplot')
sns.scatterplot(data=jr2,y='prices',x='ratings',hue='AC_type').set(title='Scatter plot based on price and ratings based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.there 2 ac buses with 4.7 ratings
#     2.there is only 1 ac bus with 4.6 rating and with less price
#     3.there is 1 non-ac bus with 4.5 star rating
#     4.high price ac buses has low price

# %%
df2=df[(df['ratings']>4.5) & (df['prices']<1000)].reset_index()
df2.drop('index',axis=1,inplace=True)
df2
# Out:
#                  Bus_Name                     Bus_type from   to pickup_time  \
# 0  VSR Tours and Travels             A/C Sleeper (2+1)  HYD  BLR       20:40
# 1        Jabbar  Travels   NON AC Seater / Sleeper 2+1  HYD  BLR       19:20
# 2      IntrCity SmartBus    A/C Seater / Sleeper (2+1)  HYD  BLR       21:00
# 3               Yolo Bus             A/C Sleeper (2+1)  HYD  BLR       19:20
# 4      IntrCity SmartBus    A/C Seater / Sleeper (2+1)  HYD  BLR       20:25
#
#   drop_time  duration  prices  ratings AC_type Seater semi_sleeper sleeper
# 0     07:15        10     899      4.7     A/C     no           no     yes
# 1     05:50        10     610      4.6     A/C    yes           no     yes
# 2     08:45        11     918      4.6     A/C    yes           no     yes
# 3     07:38        12     899      4.6     A/C     no           no     yes
# 4     09:00        12     872      4.6     A/C    yes           no     yes

# %%
df2.groupby('Bus_Name')['prices'].mean().plot(kind='bar').set(title='Average ticket prices of bus names with more ratings and price below 1000')
plt.show()

# %% [raw]
# insights:
#       1.the  bus jabbar travel has average ticket price 600
#       2.the buses intracity smartbus,vsr tours and travel and yolo buses has avg ticket price 900
#       3.these buses has highest ratings among all buses

# %% [markdown]
# ##### Scatter plot based on price and duration based on ac type

# %%
sns.scatterplot(data=jr2,x='duration',y='prices',hue='AC_type').set(title='Scatter plot based on price and duration based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.there are only 2 ac buses with 7hr duration
#     2.there are 6 ac and 2 non ac buses with 8 hr duration

# %%
df3=df[df['duration']<9].reset_index()
df3.drop('index',axis=1,inplace=True)
df3
# Out:
#                               Bus_Name  \
# 0                             DLT BUS
# 1               Swamy Ayyappa Travels
# 2                         SRS Travels
# 3   Orange Tours and Travels Platinum
# 4                Morning Star Travels
# 5                         SRS Travels
# 6                Morning Star Travels
# 7                    Northern Travels
# 8                         SRS Travels
# 9                  Tranzindia Travels
# 10                  Manikanta Travels
# 11                        VRL Travels
# 12                        VRL Travels
# 13                        VRL Travels
#
#                                        Bus_type from   to pickup_time  \
# 0                             A/C Sleeper (2+1)  HYD  BLR       23:15
# 1   Volvo Multi-Axle I-Shift  A/C Sleeper (2+1)  HYD  BLR       19:50
# 2       Scania Multi-Axle AC Semi Sleeper (2+2)  HYD  BLR       23:30
# 3            Volvo Multi-Axle Sleeper A/C (2+1)  HYD  BLR       23:20
# ...

# %%
df3.groupby('Bus_Name')['prices'].mean().plot(kind='bar').set(title='average prices of less duration buses')
plt.show()

# %% [raw]
# insights:
#      1.dlt buses has avg price of less duration is 1200
#      2.manikanta travels buses has avg price of less duration is 1000
#      3.morning star travel buses has avg price of less duration is 1500
#      4.northen travels buses has avg price of less duration is 850
#      5.orange tours and travels platinum buses has avg price of less duration is 1300
#      6.srs travels buses has avg price of less duration is 810
#      7.swamy ayyapa travels  buses has avg price of less duration is 1700
#      8.tranzindia travels  buses has avg price of less duration is 1300
#      9.vlr travels buses has avg price of less duration is 1050

# %% [markdown]
# ## Multivariate

# %% [markdown]
# ### Heatmap

# %% [markdown]
# ##### Heatmap on buses dataser

# %%
sns.heatmap(jr2.corr(numeric_only=True),annot=True).set(title='Scatter plot based on price and ratings based on ac type')
plt.show()

# %% [raw]
# insights:
#     1.the relationship between duration and ratings is postive ,very weak relationship ,the corelation coefficient is 0.16
#     2.the relationship between duration and prices is negative ,very weak relationship,the corelation coefficient is -0.23
#     3.the relationship between ratings and prices is negative, very weak relationship,the corelation coefficient is -0.22

# %% [markdown]
# ### pairplot

# %%
sns.pairplot(jr2,hue='AC_type')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(jr2,hue='Seater')
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(jr2,hue='sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(jr2,hue='semi_sleeper')
plt.show()
# Out:
# C:\Users\varsh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
